# %%
pip install dice_ml
# Out:
# Requirement already satisfied: dice_ml in /usr/local/lib/python3.12/dist-packages (0.12)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.12/dist-packages (from dice_ml) (4.26.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from dice_ml) (2.0.2)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from dice_ml) (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from dice_ml) (1.6.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from dice_ml) (4.67.3)
# Requirement already satisfied: raiutils>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from dice_ml) (0.4.2)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.12/dist-packages (from dice_ml) (3.2.0)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.12/dist-packages (from dice_ml) (4.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->dice_ml) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->dice_ml) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->dice_ml) (2025.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from raiutils>=0.4.0->dice_ml) (2.32.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from raiutils>=0.4.0->dice_ml) (1.16.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema->dice_ml) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema->dice_ml) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema->dice_ml) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema->dice_ml) (0.30.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->dice_ml) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->dice_ml) (3.6.0)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.12/dist-packages (from xgboost->dice_ml) (2.27.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->dice_ml) (1.17.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from referencing>=0.28.4->jsonschema->dice_ml) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->raiutils>=0.4.0->dice_ml) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->raiutils>=0.4.0->dice_ml) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->raiutils>=0.4.0->dice_ml) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->raiutils>=0.4.0->dice_ml) (2026.2.25)

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.10-cp312-cp312-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from catboost) (2.0.2)
# Requirement already satisfied: pandas<4.0,>=0.24 in /usr/local/lib/python3.12/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from catboost) (1.16.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0,>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0,>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0,>=0.24->catboost) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (3.3.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->catboost) (9.1.4)
# Downloading catboost-1.2.10-cp312-cp312-manylinux2014_x86_64.whl (97.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.1/97.1 MB 8.4 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.10

# %%
import pandas as pd
import numpy as np
import joblib
import dice_ml
from dice_ml import Dice
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt


# 1. LOAD DATA

df = pd.read_csv("cleaned_train.csv")

TARGET = 'target'
X = df.drop(columns=[TARGET])
y = df[TARGET]


# 2. LOAD RANDOM FOREST (FOR DICE)

rf = joblib.load("rf_model(1).pkl")



# 3. LOAD CATBOOST MODEL (FOR RISK)

catboost_model = joblib.load("catboost_model (1).pkl")

# Probability function
def predict_proba(model, df):
    return model.predict_proba(df)[:,1]


# 4. LOAD HRS RISK CATEGORIES

hrs = pd.read_csv("hrs_risk_categories (1).csv")
hrs.columns = hrs.columns.str.lower()

high_risk_ids = hrs[hrs['risk_class'].str.lower() == 'high'].index

df = df.reset_index(drop=True)
high_risk_df = df.iloc[high_risk_ids]

print("Total HRS High Risk Patients:", len(high_risk_df))

# CatBoost filter
preds = (predict_proba(catboost_model, high_risk_df[X.columns]) > 0.5).astype(int)
high_risk_df = high_risk_df[preds == 1]

print("After CatBoost filter:", len(high_risk_df))


# 5. DiCE SETUP

data_dice = dice_ml.Data(
    dataframe=df,
    continuous_features=list(X.columns),
    outcome_name=TARGET
)

model_dice = dice_ml.Model(model=rf, backend="sklearn")
dice = Dice(data_dice, model_dice)


# 6. MEDICAL CONSTRAINTS





features_to_vary = ['trestbps', 'oldpeak', 'thalch', 'chol', 'ca']

immutable_features = ['age', 'sex_Male']

permitted_range = {
    'trestbps': [-1.5, 1.5],
    'oldpeak': [-2, 1],
    'thalch': [-1, 2],
    'chol': [-2, 1.5],
    'ca': [-2, 0]
}

data_dice = dice_ml.Data(
    dataframe=df,
    continuous_features=list(X.columns),
    outcome_name=TARGET,
    immutable_features=immutable_features
)



# 7. GENERATE COUNTERFACTUALS FOR ALL HIGH RISK

query_instances_clean = high_risk_df[X.columns]

cf = dice.generate_counterfactuals(
    query_instances_clean,
    total_CFs=3,
    desired_class=0,
    features_to_vary=features_to_vary,
    permitted_range=permitted_range
)


# 8. COUNTERFACTUAL IMPACT PLOT (CORRECT)

feature_changes = []

for cf_example in cf.cf_examples_list:
    original = cf_example.test_instance_df
    cfs = cf_example.final_cfs_df

    if cfs is None:
        continue

    for i in range(len(cfs)):
        for col in features_to_vary:
            diff = abs(cfs.iloc[i][col] - original.iloc[0][col])
            feature_changes.append({"feature": col, "change": diff})

plot_df = pd.DataFrame(feature_changes)
plot_df = plot_df.groupby("feature")["change"].mean().reset_index()
plot_df = plot_df.sort_values(by="change", ascending=True)

plt.figure()
plt.barh(plot_df["feature"], plot_df["change"])
plt.title("Counterfactual Feature Importance (Average Absolute Change)")
plt.xlabel("Average Change Required")
plt.tight_layout()
plt.savefig("Counterfactual_Impact.png")
plt.show()



# 9. TABLE 11 – COUNTERFACTUAL TABLE (ALL PATIENTS)

tables = []

for idx in range(len(cf.cf_examples_list)):
    cf_example = cf.cf_examples_list[idx]
    original = cf_example.test_instance_df
    cfs = cf_example.final_cfs_df

    if cfs is None:
        continue

    original_prob = predict_proba(catboost_model, original[X.columns])[0]
    original["risk"] = original_prob

    for i in range(len(cfs)):
        cf_prob = predict_proba(catboost_model, cfs.iloc[[i]][X.columns])[0]
        cfs.loc[cfs.index[i], "risk"] = cf_prob

    table = pd.concat([original, cfs])
    table["patient"] = idx+1
    tables.append(table)

counterfactual_table = pd.concat(tables)
counterfactual_table.to_csv("Counterfactual_Table.csv", index=False)


# 10. TABLE 13 – COUNTERFACTUAL SUMMARY

summary_rows = []

for idx in range(len(cf.cf_examples_list)):
    cf_example = cf.cf_examples_list[idx]
    original = cf_example.test_instance_df
    cfs = cf_example.final_cfs_df

    if cfs is None:
        continue

    original_prob = predict_proba(catboost_model, original[X.columns])[0]

    for j in range(len(cfs)):
        cf_instance = cfs.iloc[[j]]
        cf_prob = predict_proba(catboost_model, cf_instance[X.columns])[0]

        risk_reduction = ((original_prob - cf_prob) / original_prob) * 100

        changes = []
        for col in features_to_vary:
            original_val = original.iloc[0][col]
            new_val = cf_instance.iloc[0][col]
            if abs(original_val - new_val) > 0.1:
                changes.append(col)

        summary_rows.append({
            "Patient": idx+1,
            "Changed Features": ", ".join(changes),
            "Original Risk": round(original_prob,3),
            "New Risk": round(cf_prob,3),
            "% Risk Reduction": round(risk_reduction,2)
        })

summary_df = pd.DataFrame(summary_rows)
summary_df.to_csv("Counterfactual_Summary.csv", index=False)


# 11. CLINICAL EXPLANATIONS

print("\nNARRATIVE COUNTERFACTUAL EXPLANATIONS WITH AMOUNT")

for idx in range(len(cf.cf_examples_list)):
    cf_example = cf.cf_examples_list[idx]
    original = cf_example.test_instance_df
    cfs = cf_example.final_cfs_df

    if cfs is None:
        continue

    original_prob = predict_proba(catboost_model, original[X.columns])[0]

    for j in range(len(cfs)):
        cf_instance = cfs.iloc[[j]]
        cf_prob = predict_proba(catboost_model, cf_instance[X.columns])[0]

        narrative = f"Patient {idx+1} had a predicted heart disease risk of {original_prob:.2f}. "
        narrative += "The risk could be reduced to "
        narrative += f"{cf_prob:.2f} if "

        changes_text = []
        for col in features_to_vary:
            original_val = original.iloc[0][col]
            new_val = cf_instance.iloc[0][col]
            diff = new_val - original_val

            if abs(diff) > 0.1:
                if diff > 0:
                    changes_text.append(f"{col} is increased by {abs(diff):.2f}")
                else:
                    changes_text.append(f"{col} is decreased by {abs(diff):.2f}")

        narrative += ", ".join(changes_text)
        narrative += "."

        print(narrative)
print("This is an AI-generated suggestion and not real medical advice. Consult a doctor."
)
# Out:
# Total HRS High Risk Patients: 61
# After CatBoost filter: 32
#  84%|████████▍ | 27/32 [06:29<01:17, 15.54s/it]
# No Counterfactuals found for the given configuration, perhaps try with different parameters... ; total time taken: 00 min 00 sec
# 100%|██████████| 32/32 [06:30<00:00, 12.20s/it]
# NARRATIVE COUNTERFACTUAL EXPLANATIONS WITH AMOUNT
# Patient 1 had a predicted heart disease risk of 0.51. The risk could be reduced to 0.35 if thalch is increased by 1.59, ca is decreased by 0.52.
# Patient 1 had a predicted heart disease risk of 0.51. The risk could be reduced to 0.27 if thalch is increased by 0.73, ca is decreased by 1.15.
# Patient 1 had a predicted heart disease risk of 0.51. The risk could be reduced to 0.34 if oldpeak is decreased by 1.68, thalch is decreased by 0.93.
# Patient 2 had a predicted heart disease risk of 0.91. The risk could be reduced to 0.56 if oldpeak is decreased by 0.90, thalch is increased by 0.64, ca is decreased by 0.67.
# Patient 2 had a predicted heart disease risk of 0.91. The risk could be reduced to 0.39 if oldpeak is decreased by 1.81, thalch is increased by 1.73, ca is decreased by 1.99.
# Patient 2 had a predicted heart disease risk of 0.91. The risk could be reduced to 0.53 if oldpeak is decreased by 2.90, thalch is increased by 1.42, ca is decreased by 1.55.
# Patient 3 had a predicted heart disease risk of 0.97. The risk could be reduced to 0.60 if trestbps is decreased by 1.33, oldpeak is decreased by 1.73, thalch is increased by 1.45, ca is decreased by 5.70.
# Patient 3 had a predicted heart disease risk of 0.97. The risk could be reduced to 0.48 if oldpeak is decreased by 2.00, thalch is increased by 2.11, chol is decreased by 0.17, ca is decreased by 5.32.
# Patient 3 had a predicted heart disease risk of 0.97. The risk could be reduced to 0.47 if oldpeak is decreased by 1.55, thalch is increased by 2.07, chol is decreased by 2.28, ca is decreased by 5.02.
# Patient 4 had a predicted heart disease risk of 0.87. The risk could be reduced to 0.50 if trestbps is increased by 2.06, chol is increased by 1.40.
# Patient 4 had a predicted heart disease risk of 0.87. The risk could be reduced to 0.55 if chol is increased by 0.78, ca is decreased by 1.21.
# Patient 4 had a predicted heart disease risk of 0.87. The risk could be reduced to 0.55 if chol is increased by 0.56, ca is decreased by 1.05.
# Patient 5 had a predicted heart disease risk of 0.67. The risk could be reduced to 0.30 if thalch is increased by 1.26, ca is decreased by 0.97.
# Patient 5 had a predicted heart disease risk of 0.67. The risk could be reduced to 0.25 if thalch is increased by 2.48, ca is decreased by 1.04.
# Patient 5 had a predicted heart disease risk of 0.67. The risk could be reduced to 0.33 if thalch is increased by 1.97, ca is decreased by 0.82.
# Patient 6 had a predicted heart disease risk of 0.87. The risk could be reduced to 0.63 if oldpeak is decreased by 2.20, thalch is increased by 1.58.
# Patient 6 had a predicted heart disease risk of 0.87. The risk could be reduced to 0.69 if oldpeak is decreased by 0.98.
# Patient 6 had a predicted heart disease risk of 0.87. The risk could be reduced to 0.48 if oldpeak is decreased by 1.65, ca is decreased by 1.89.
# Patient 7 had a predicted heart disease risk of 0.77. The risk could be reduced to 0.42 if thalch is increased by 0.43, chol is increased by 1.71.
# Patient 7 had a predicted heart disease risk of 0.77. The risk could be reduced to 0.40 if chol is increased by 2.70.
# Patient 7 had a predicted heart disease risk of 0.77. The risk could be reduced to 0.45 if thalch is increased by 0.56, chol is increased by 3.07.
# Patient 8 had a predicted heart disease risk of 0.71. The risk could be reduced to 0.40 if ca is decreased by 1.98.
# Patient 8 had a predicted heart disease risk of 0.71. The risk could be reduced to 0.71 if ca is decreased by 0.46.
# Patient 8 had a predicted heart disease risk of 0.71. The risk could be reduced to 0.38 if oldpeak is decreased by 2.67, ca is decreased by 0.79.
# Patient 9 had a predicted heart disease risk of 0.97. The risk could be reduced to 0.58 if trestbps is decreased by 2.09, oldpeak is decreased by 1.97, chol is increased by 3.23, ca is decreased by 1.92.
# Patient 9 had a predicted heart disease risk of 0.97. The risk could be reduced to 0.61 if oldpeak is decreased by 2.16, thalch is increased by 3.98, chol is increased by 0.64, ca is decreased by 1.39.
# Patient 9 had a predicted heart disease risk of 0.97. The risk could be reduced to 0.66 if trestbps is decreased by 1.94, oldpeak is decreased by 1.85, chol is increased by 1.40, ca is decreased by 0.73.
# Patient 10 had a predicted heart disease risk of 0.98. The risk could be reduced to 0.54 if oldpeak is decreased by 2.40, ca is decreased by 1.96.
# Patient 10 had a predicted heart disease risk of 0.98. The risk could be reduced to 0.55 if oldpeak is decreased by 2.67, ca is decreased by 1.96.
# Patient 10 had a predicted heart disease risk of 0.98. The risk could be reduced to 0.59 if oldpeak is decreased by 3.09, ca is decreased by 1.67.
# Patient 11 had a predicted heart disease risk of 0.80. The risk could be reduced to 0.25 if oldpeak is decreased by 0.31, chol is increased by 2.85.
# Patient 11 had a predicted heart disease risk of 0.80. The risk could be reduced to 0.17 if chol is increased by 2.83, ca is decreased by 0.93.
# Patient 11 had a predicted heart disease risk of 0.80. The risk could be reduced to 0.23 if chol is increased by 3.28.
# Patient 12 had a predicted heart disease risk of 0.90. The risk could be reduced to 0.37 if thalch is increased by 2.03, chol is increased by 1.52, ca is decreased by 1.09.
# Patient 12 had a predicted heart disease risk of 0.90. The risk could be reduced to 0.43 if thalch is increased by 1.39, chol is increased by 2.16, ca is decreased by 1.00.
# Patient 12 had a predicted heart disease risk of 0.90. The risk could be reduced to 0.43 if thalch is increased by 1.55, chol is increased by 2.15, ca is decreased by 0.61.
# Patient 13 had a predicted heart disease risk of 0.96. The risk could be reduced to 0.62 if thalch is increased by 0.31, ca is decreased by 3.88.
# Patient 13 had a predicted heart disease risk of 0.96. The risk could be reduced to 0.61 if oldpeak is decreased by 1.98, ca is decreased by 3.29.
# Patient 13 had a predicted heart disease risk of 0.96. The risk could be reduced to 0.54 if oldpeak is decreased by 1.15, ca is decreased by 3.86.
# Patient 14 had a predicted heart disease risk of 0.64. The risk could be reduced to 0.68 if oldpeak is decreased by 1.00.
# Patient 14 had a predicted heart disease risk of 0.64. The risk could be reduced to 0.69 if oldpeak is decreased by 1.49.
# Patient 14 had a predicted heart disease risk of 0.64. The risk could be reduced to 0.63 if thalch is increased by 1.96.
# Patient 15 had a predicted heart disease risk of 0.52. The risk could be reduced to 0.53 if trestbps is increased by 0.49, ca is decreased by 1.92.
# Patient 15 had a predicted heart disease risk of 0.52. The risk could be reduced to 0.42 if oldpeak is decreased by 0.66.
# Patient 15 had a predicted heart disease risk of 0.52. The risk could be reduced to 0.72 if trestbps is increased by 1.52.
# Patient 16 had a predicted heart disease risk of 0.68. The risk could be reduced to 0.41 if oldpeak is decreased by 1.22, ca is decreased by 0.86.
# Patient 16 had a predicted heart disease risk of 0.68. The risk could be reduced to 0.56 if oldpeak is decreased by 1.95, chol is decreased by 0.99.
# Patient 16 had a predicted heart disease risk of 0.68. The risk could be reduced to 0.41 if oldpeak is decreased by 1.09, ca is decreased by 1.79.
# Patient 17 had a predicted heart disease risk of 0.69. The risk could be reduced to 0.35 if thalch is increased by 2.26, ca is decreased by 1.47.
# Patient 17 had a predicted heart disease risk of 0.69. The risk could be reduced to 0.58 if trestbps is increased by 0.95, thalch is increased by 1.94.
# Patient 17 had a predicted heart disease risk of 0.69. The risk could be reduced to 0.35 if thalch is increased by 2.26, ca is decreased by 1.83.
# Patient 18 had a predicted heart disease risk of 0.71. The risk could be reduced to 0.39 if oldpeak is decreased by 1.60, ca is decreased by 1.12.
# Patient 18 had a predicted heart disease risk of 0.71. The risk could be reduced to 0.31 if thalch is increased by 1.99, ca is decreased by 1.12.
# Patient 18 had a predicted heart disease risk of 0.71. The risk could be reduced to 0.35 if thalch is increased by 1.78, ca is decreased by 1.74.
# Patient 19 had a predicted heart disease risk of 0.98. The risk could be reduced to 0.50 if oldpeak is decreased by 3.07, thalch is increased by 2.73, ca is decreased by 1.77.
# Patient 19 had a predicted heart disease risk of 0.98. The risk could be reduced to 0.50 if oldpeak is decreased by 2.30, thalch is increased by 2.64, ca is decreased by 0.89.
# Patient 19 had a predicted heart disease risk of 0.98. The risk could be reduced to 0.51 if oldpeak is decreased by 3.37, thalch is increased by 2.64, ca is decreased by 0.93.
# Patient 20 had a predicted heart disease risk of 0.95. The risk could be reduced to 0.40 if oldpeak is decreased by 2.59, ca is decreased by 0.90.
# Patient 20 had a predicted heart disease risk of 0.95. The risk could be reduced to 0.37 if oldpeak is decreased by 2.24, ca is decreased by 1.89.
# Patient 20 had a predicted heart disease risk of 0.95. The risk could be reduced to 0.43 if oldpeak is decreased by 2.92, ca is decreased by 1.26.
# Patient 21 had a predicted heart disease risk of 0.86. The risk could be reduced to 0.62 if chol is increased by 2.85, ca is decreased by 0.96.
# Patient 21 had a predicted heart disease risk of 0.86. The risk could be reduced to 0.63 if chol is increased by 2.58, ca is decreased by 1.27.
# Patient 21 had a predicted heart disease risk of 0.86. The risk could be reduced to 0.52 if thalch is increased by 0.70, ca is decreased by 1.23.
# Patient 22 had a predicted heart disease risk of 0.76. The risk could be reduced to 0.54 if ca is decreased by 1.10.
# Patient 22 had a predicted heart disease risk of 0.76. The risk could be reduced to 0.54 if ca is decreased by 1.57.
# Patient 22 had a predicted heart disease risk of 0.76. The risk could be reduced to 0.54 if ca is decreased by 0.96.
# Patient 23 had a predicted heart disease risk of 0.98. The risk could be reduced to 0.52 if oldpeak is decreased by 3.91, thalch is increased by 2.29, ca is decreased by 1.56.
# Patient 23 had a predicted heart disease risk of 0.98. The risk could be reduced to 0.57 if oldpeak is decreased by 4.32, thalch is increased by 2.09, ca is decreased by 1.27.
# Patient 23 had a predicted heart disease risk of 0.98. The risk could be reduced to 0.67 if oldpeak is decreased by 2.43, thalch is increased by 1.67, ca is decreased by 1.67.
# Patient 24 had a predicted heart disease risk of 0.75. The risk could be reduced to 0.55 if thalch is increased by 1.66.
# Patient 24 had a predicted heart disease risk of 0.75. The risk could be reduced to 0.32 if chol is decreased by 2.67.
# Patient 24 had a predicted heart disease risk of 0.75. The risk could be reduced to 0.55 if thalch is increased by 1.54.
# Patient 25 had a predicted heart disease risk of 0.95. The risk could be reduced to 0.65 if oldpeak is decreased by 2.16, chol is decreased by 0.28, ca is decreased by 0.80.
# Patient 25 had a predicted heart disease risk of 0.95. The risk could be reduced to 0.57 if oldpeak is decreased by 1.81, thalch is increased by 1.19, ca is decreased by 1.41.
# Patient 25 had a predicted heart disease risk of 0.95. The risk could be reduced to 0.66 if oldpeak is decreased by 2.35, chol is decreased by 0.23, ca is decreased by 0.80.
# Patient 26 had a predicted heart disease risk of 0.98. The risk could be reduced to 0.64 if thalch is increased by 1.98, ca is decreased by 1.84.
# Patient 26 had a predicted heart disease risk of 0.98. The risk could be reduced to 0.65 if thalch is increased by 1.07, ca is decreased by 2.53.
# Patient 26 had a predicted heart disease risk of 0.98. The risk could be reduced to 0.65 if thalch is increased by 1.13, ca is decreased by 1.27.
# Patient 28 had a predicted heart disease risk of 0.76. The risk could be reduced to 0.34 if trestbps is decreased by 4.08, thalch is increased by 1.10.
# Patient 28 had a predicted heart disease risk of 0.76. The risk could be reduced to 0.32 if oldpeak is decreased by 1.90, thalch is increased by 1.49.
# Patient 28 had a predicted heart disease risk of 0.76. The risk could be reduced to 0.30 if trestbps is decreased by 4.04, oldpeak is decreased by 1.32.
# Patient 29 had a predicted heart disease risk of 0.98. The risk could be reduced to 0.32 if oldpeak is decreased by 4.06, ca is decreased by 5.03.
# Patient 29 had a predicted heart disease risk of 0.98. The risk could be reduced to 0.35 if oldpeak is decreased by 3.71, ca is decreased by 5.77.
# Patient 29 had a predicted heart disease risk of 0.98. The risk could be reduced to 0.68 if thalch is increased by 1.74, ca is decreased by 6.03.
# Patient 30 had a predicted heart disease risk of 0.99. The risk could be reduced to 0.76 if trestbps is decreased by 0.95, oldpeak is decreased by 1.51, thalch is increased by 2.59, ca is decreased by 3.64.
# Patient 31 had a predicted heart disease risk of 0.56. The risk could be reduced to 0.31 if trestbps is decreased by 2.02, ca is decreased by 1.80.
# Patient 31 had a predicted heart disease risk of 0.56. The risk could be reduced to 0.48 if thalch is increased by 2.45, chol is increased by 0.24.
# Patient 31 had a predicted heart disease risk of 0.56. The risk could be reduced to 0.23 if thalch is increased by 0.92, ca is decreased by 0.68.
# Patient 32 had a predicted heart disease risk of 0.91. The risk could be reduced to 0.46 if oldpeak is decreased by 2.08, thalch is increased by 0.79, ca is decreased by 0.75.
# Patient 32 had a predicted heart disease risk of 0.91. The risk could be reduced to 0.43 if oldpeak is decreased by 1.47, thalch is increased by 1.05, ca is decreased by 1.50.
# Patient 32 had a predicted heart disease risk of 0.91. The risk could be reduced to 0.45 if oldpeak is decreased by 1.97, thalch is increased by 0.90, ca is decreased by 1.09.
# This is an AI-generated suggestion and not real medical advice. Consult a doctor.
